# %% [markdown]
# # Objectives
# Analyse the number of cyclists in Paris
#
# * Quantify the rise of cyclists in Paris
#     * Get data from traffic, accidents
#     * Bike lane construction
# * Correlate the accidents with time of day, condition of the road, gender
# * Is the increase in car traffic leading to more bike accidents?
# * Is the increase bikes lanes helping in the drecrease of bike accidents?
# * Is the increase of bike traffic leading to more bike lanes? And in which areas?

# %% [markdown]
# # Data that we might need (to scrape)
# * Public investment (bike lane construction, public incentives to buy bikes)
# * Car Traffic in Paris
# * Number of bycicles sold in Paris (we might have info about sales of eletric bikes in Paris)
# * Average Salary in Paris
# * Average bike prices

# %%
import pandas as pd

# %%
# Importing the accidents dataset - Imports with no issues
accidents = pd.read_csv('https://www.data.gouv.fr/en/datasets/r/3d5f2317-5afd-4a9f-a9c5-bd4fe0113f39', low_memory=False)
# Out:
#    identifiant accident        date          mois          jour  heure  \
# 0          200500000030  2005-01-13  01 - janvier     3 - jeudi   19.0
# 1          200500000034  2005-01-19  01 - janvier  2 - mercredi   10.0
# 2          200500000078  2005-01-26  01 - janvier  2 - mercredi   13.0
# 3          200500000093  2005-01-03  01 - janvier     0 - lundi   13.0
# 4          200500000170  2005-01-29  01 - janvier    5 - samedi   18.0
#
#   departement commune     lat    lon en agglomeration  ... existence securite  \
# 0          62   62331  50.300  2.840              oui  ...                NaN
# 1          62   62022   0.000  0.000              non  ...                NaN
# 2          02   02173   0.000  0.000              non  ...             Casque
# 3          02   02810  49.255  3.094              oui  ...                NaN
# 4          76   76196   0.000  0.000              non  ...              Autre
#
#   usage securite obstacle fixe heurte obstacle mobile heurte  \
# 0            NaN                  NaN               Véhicule
# 1            NaN                  NaN               Véhicule
# 2            Non                  NaN               Véhicule
# 3            NaN                  NaN               Véhicule
# 4            Oui                  NaN               Véhicule
#
#   localisation choc      manoeuvre avant accident  identifiant vehicule  \
# 0       Côté gauche    Changeant de file à gauche       200500000030B02
# 1             Avant  Sans changement de direction       200500000034B02
# 2             Avant  Sans changement de direction       200500000078B02
# 3      Avant gauche          Manœuvre d’évitement       200500000093B02
# 4           Arrière          Même sens, même file       200500000170A01
#
#                                type autres vehicules  \
# 0                                Transport en commun
# 1  VU seul 1,5T <= PTAC <= 3,5T avec ou sans remo...
# 2                                            VL seul
# 3                                            VL seul
# 4  VU seul 1,5T <= PTAC <= 3,5T avec ou sans remo...
#
#   manoeuvre autres vehicules  nombre autres vehicules
# 0         Dépassant à gauche                      1.0
# 1          Tournant à gauche                      1.0
# 2          Tournant à gauche                      1.0
# 3       Manœuvre d’évitement                      1.0
# 4       Même sens, même file                      1.0
#
# [5 rows x 39 columns]

# %%
# Importing the bike lanes dataset
# The CSV file is in the wrong format because it doesn't have a delimiter and it is already separated
# Because of that, the read_csv function is having trouble reading the file
# The error_bad_lines parameter ignores the rows that can't read, so those are not imported
# However even after the import, the dataframe is in the wrong format
#Solved it! It was the separator, which is a ; instead of a comma...
bike_lanes = pd.read_csv('https://www.data.gouv.fr/en/datasets/r/1211e838-4b77-4ee4-9567-03d78d55f0bf', sep=';')
bike_lanes
# Out:
#                                                Typologie  \
# 0                      Couloirs de bus ouverts aux vélos
# 1                                       Pistes cyclables
# 2                      Couloirs de bus ouverts aux vélos
# 3                      Couloirs de bus ouverts aux vélos
# 4                                       Bandes cyclables
# ...                                                  ...
# 11949                                   Pistes cyclables
# 11950                                   Bandes cyclables
# 11951                  Couloirs de bus ouverts aux vélos
# 11952  Autres itinéraires cyclables (ex : Aires piéto...
# 11953                                   Bandes cyclables
#
#       Aménagement bidirectionnel Régime de vitesse  \
# 0                            Non           Voie 50
# 1                            Non           Voie 50
# 2                            Oui           Voie 50
# 3                            Oui           Voie 50
# 4                            Non           Voie 50
# ...                          ...               ...
# 11949                        Non           Voie 50
# 11950                        NaN           Zone 30
# 11951                        Non           Voie 50
# 11952                        NaN           Zone 30
# 11953                        NaN           Zone 30
#
#                           Sens vélo                       Voie  \
# 0      Sens de circulation générale    BOULEVARD DE SEBASTOPOL
# 1      Sens de circulation générale   BOULEVARD VINCENT AURIOL
# 2      Sens de circulation générale     BOULEVARD DE L HOPITAL
# 3      Sens de circulation générale            PLACE VALHUBERT
# 4      Sens de circulation générale            AVENUE D ITALIE
# ...                             ...                        ...
# 11949  Sens de circulation générale  Avenue des Champs-Elysées
# 11950                    Contresens                Rue Gérando
# 11951  Sens de circulation générale       RUE DE LA CONVENTION
# 11952                    Contresens           Rue Hélène Brion
# 11953                    Contresens          Rue du Chevaleret
#
#        Arrondissement Bois  Longueur du tronçon en m  \
# 0                 4.0  Non                152.999231
# 1                13.0  Non                 14.263221
# 2                13.0  Non                 17.421704
# 3                13.0  Non                  7.371715
# 4                13.0  Non                172.387831
# ...               ...  ...                       ...
# 11949             8.0  Non                  8.093520
# 11950             9.0  NaN                 24.791335
# 11951            15.0  Non                128.784477
# 11952            13.0  NaN                233.651642
# 11953            13.0  NaN                141.856556
#
#        Longueur du tronçon en km Position aménagement  \
# 0                       0.152999                  NaN
# 1                       0.014263              Latéral
# 2                       0.017422                  NaN
# 3                       0.007372                  NaN
# 4                       0.172388                  NaN
# ...                          ...                  ...
# 11949                   0.008094              Latéral
# 11950                   0.024791                  NaN
# 11951                   0.128784                  NaN
# 11952                   0.233652                  NaN
# 11953                   0.141857                  NaN
#
#       Circulation générale interdite            Piste Couloir bus  \
# 0                                NaN              NaN      Marqué
# 1                                NaN  Niveau chaussée         NaN
# 2                                NaN              NaN     Protégé
# 3                                NaN              NaN     Protégé
# 4                                NaN              NaN         NaN
# ...                              ...              ...         ...
# 11949                            Non  Niveau chaussée         NaN
# 11950                            NaN              NaN         NaN
# 11951                            NaN              NaN      Marqué
# 11952                            NaN              NaN         NaN
# 11953                            NaN              NaN         NaN
#
#           Continuité cyclable Réseau cyclable Date de livraison  \
# 0                         NaN             NaN               NaN
# 1                         NaN             NaN        2019-09-15
# 2                         NaN             NaN        2008-12-31
# 3                         NaN             NaN        2008-12-31
# 4                         NaN             NaN        2005-12-31
# ...                       ...             ...               ...
# 11949          Passage piéton            REVe        2018-12-31
# 11950  Traversée de carrefour             NaN        2018-05-31
# 11951                     NaN             NaN               NaN
# 11952                     NaN             NaN        2020-03-31
# 11953                     NaN             NaN        2020-03-31
#
#                                                geo_shape  \
# 0      {"type": "LineString", "coordinates": [[2.3494...
# 1      {"type": "LineString", "coordinates": [[2.3671...
# 2      {"type": "LineString", "coordinates": [[2.3619...
# 3      {"type": "LineString", "coordinates": [[2.3648...
# 4      {"type": "LineString", "coordinates": [[2.3586...
# ...                                                  ...
# 11949  {"type": "LineString", "coordinates": [[2.3051...
# 11950  {"type": "LineString", "coordinates": [[2.3456...
# 11951  {"type": "LineString", "coordinates": [[2.2947...
# 11952  {"type": "LineString", "coordinates": [[2.3807...
# 11953  {"type": "LineString", "coordinates": [[2.3772...
#
#                       geo_point_2d
# 0      48.8612701514,2.34981742995
# 1      48.8345003893,2.36725670179
# 2        48.84004249,2.36196441128
# 3      48.8437491231,2.36486970584
# 4      48.8213113974,2.35888981211
# ...                            ...
# 11949  48.8707118641,2.30508325736
# 11950  48.8823341253,2.34571978805
# 11951  48.8376085136,2.29549533312
# 11952  48.8286149251,2.38210139819
# 11953  48.8279417627,2.37688895752
#
# [11954 rows x 18 columns]

# %%
# Importing the traffic dataset
# Same problem as the bike lane dataset. Even though it doesn't give an error when reading the file,
# the dataframe is in the wrong format as well.
# Problem solved! It was the same problem with the separator.
traffic = pd.read_csv('https://www.data.gouv.fr/en/datasets/r/237382af-0e7a-4ef8-9508-b3e9e78adcfd', sep=';')

# %%
traffic
# Out:
#        Identifiant du compteur                    Nom du compteur  \
# 0                 100003096-SC  97 avenue Denfert Rochereau SO-NE
# 1                 100003096-SC  97 avenue Denfert Rochereau SO-NE
# 2                 100003096-SC  97 avenue Denfert Rochereau SO-NE
# 3                 100003096-SC  97 avenue Denfert Rochereau SO-NE
# 4                 100003096-SC  97 avenue Denfert Rochereau SO-NE
# ...                        ...                                ...
# 762305            100063173-SC            74 Boulevard Ornano S-N
# 762306            100063173-SC            74 Boulevard Ornano S-N
# 762307            100063173-SC            74 Boulevard Ornano S-N
# 762308            100063173-SC            74 Boulevard Ornano S-N
# 762309            100063173-SC            74 Boulevard Ornano S-N
#
#         Identifiant du site de comptage            Nom du site de comptage  \
# 0                             100003096  97 avenue Denfert Rochereau SO-NE
# 1                             100003096  97 avenue Denfert Rochereau SO-NE
# 2                             100003096  97 avenue Denfert Rochereau SO-NE
# 3                             100003096  97 avenue Denfert Rochereau SO-NE
# 4                             100003096  97 avenue Denfert Rochereau SO-NE
# ...                                 ...                                ...
# 762305                        100063173            74 Boulevard Ornano S-N
# 762306                        100063173            74 Boulevard Ornano S-N
# 762307                        100063173            74 Boulevard Ornano S-N
# 762308                        100063173            74 Boulevard Ornano S-N
# 762309                        100063173            74 Boulevard Ornano S-N
#
#         Comptage horaire  Date et heure de comptage  \
# 0                      1  2019-08-01T04:00:00+02:00
# 1                      0  2019-08-01T06:00:00+02:00
# 2                      0  2019-08-01T03:00:00+02:00
# 3                      6  2019-08-01T07:00:00+02:00
# 4                     21  2019-08-01T08:00:00+02:00
# ...                  ...                        ...
# 762305                 0  2020-09-17T07:00:00+02:00
# 762306                 0  2020-09-17T10:00:00+02:00
# 762307                 0  2020-09-17T13:00:00+02:00
# 762308                 0  2020-09-17T15:00:00+02:00
# 762309                 0  2020-09-17T17:00:00+02:00
#
#        Date d'installation du site de comptage  \
# 0                                   2012-02-22
# 1                                   2012-02-22
# 2                                   2012-02-22
# 3                                   2012-02-22
# 4                                   2012-02-22
# ...                                        ...
# 762305                              2020-07-22
# 762306                              2020-07-22
# 762307                              2020-07-22
# 762308                              2020-07-22
# 762309                              2020-07-22
#
#                       Lien vers photo du site de comptage  \
# 0       https://www.eco-visio.net/Photos/100003096/157...
# 1       https://www.eco-visio.net/Photos/100003096/157...
# 2       https://www.eco-visio.net/Photos/100003096/157...
# 3       https://www.eco-visio.net/Photos/100003096/157...
# 4       https://www.eco-visio.net/Photos/100003096/157...
# ...                                                   ...
# 762305  https://www.eco-visio.net/Photos/100063173/159...
# 762306  https://www.eco-visio.net/Photos/100063173/159...
# 762307  https://www.eco-visio.net/Photos/100063173/159...
# 762308  https://www.eco-visio.net/Photos/100063173/159...
# 762309  https://www.eco-visio.net/Photos/100063173/159...
#
#        Coordonnées géographiques
# 0               48.83511,2.33338
# 1               48.83511,2.33338
# 2               48.83511,2.33338
# 3               48.83511,2.33338
# 4               48.83511,2.33338
# ...                          ...
# 762305        48.896825,2.345648
# 762306        48.896825,2.345648
# 762307        48.896825,2.345648
# 762308        48.896825,2.345648
# 762309        48.896825,2.345648
#
# [762310 rows x 9 columns]

# %% [markdown]
# ## Columns that we don't need from accidents
# * Circulation (143 non-missing values)

# %% [markdown]
# ### We can use pd.merge to merge the postal code dataframe with the main dataframe
